# %% [markdown]
# # Title: Lab 5

# %% [markdown]
# # purpose: Record 10 sets of visual reaction times then record 10 sets of auditory reaction times.

# %% [markdown]
# # Procedures 1 :  Each time your lab partner quietly clicks the event marker button, the green line coming in from the right side of the computer screen will jump up then back down. As soon as the subject sees the green kine jump up , they need to press the enter key as quickley as possible. when this happens a small "Enter Mark Text windowwill pop up , ignore it . However, the subject will have to click on the "Enter " key to clear it . do not worry, the mark line will still be in the right place. The subject will have to hit the "Enter" key twice for every trial: once to leave the mark line and a second time to clear the "Enter Mark Text" pop up window. Repeat this for ten trials but the lab partner should be sure to click Event marker button at irregular intervals(not less than 5 seconds apart, but not more than 10 seconds apart). After ten trials click the "stop" button ( it's the same buttoon ( it's the same button that turns from red "Rec" button to the black "stop" nutton once it is recording).

# %% [markdown]
# # Results:

# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 260.3
AUD1_MEAN = 658.7
VIS1_STD = 18.31
AUD1_STD = 187.33

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')

# %% [markdown]
# # Discussion: Based on the data produced through the ten triasl of each test, it is clear that the visual recation displayed has a faster reaction time than the auditory reaction time.

# %% [markdown]
# # Conclusion : The results that came up from these trials will never perfectly match with the reaction times of any other person. Every one has diiferent reaction times and are more stimulated by once sence than another.
